# %%
import numpy as np
import os
import glob
import math
import numpy as np
import cv2
from PIL import Image
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D
from math import log10
import SRCNN

# %%
# %run SRCNN.ipynb
# --- SRCNN Modeli ve Eğitim Sınıfı ---
class SRCNN_Train:
    def __init__(self, train_path, val_path, nImgs, nEpochs, batch_size, print_every, model_path, output_path):
        self.train_path = train_path
        self.val_path = val_path
        self.nImgs = nImgs
        self.nEpochs = nEpochs
        self.batch_size = batch_size
        self.print_every = print_every
        self.model_path = model_path
        self.output_path = output_path
        self.nIters = int(self.nImgs * self.nEpochs / self.batch_size)

        self.data_files = glob.glob(os.path.join(self.train_path, 'Data', '*.png'))[:nImgs]
        self.label_files = glob.glob(os.path.join(self.train_path, 'Labels', '*.png'))[:nImgs]

        print(f"Number of data files: {len(self.data_files)}")
        print(f"Number of label files: {len(self.label_files)}")

        self.mean, self.stddev = self.calculate_mean_stddev()

        self.model = SRCNN()

        # build işlemi için dummy input kullan
        dummy_input = tf.zeros((1, 256, 256, 3))
        _ = self.model(dummy_input)
        self.model.summary()

        self.model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='mean_squared_error')

    def calculate_mean_stddev(self):
        all_images = []
        for file in self.data_files:
            try:
                with open(file, 'rb') as f:
                    file_bytes = np.asarray(bytearray(f.read()), dtype=np.uint8)
                    img = cv2.imdecode(file_bytes, cv2.IMREAD_COLOR)
                if img is not None:
                    img = cv2.resize(img, (256, 256))
                    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Ekleyin
                    all_images.append(img.astype(np.float32))
            except Exception as e:
                print(f"Hata oluştu: {file} - {e}")

        if len(all_images) == 0:
            raise ValueError("Hiçbir görüntü okunamadı.")

        all_images = np.array(all_images)
        mean = np.mean(all_images, axis=(0, 1, 2))
        stddev = np.std(all_images, axis=(0, 1, 2))
        print(f"Calculated mean: {mean}")
        print(f"Calculated stddev: {stddev}")
        return mean, stddev

    def read_batch(self):
        idx = np.random.choice(len(self.data_files), self.batch_size, replace=False)
        imgs, labels = [], []

        for i in idx:
            try:
                with open(self.data_files[i], 'rb') as f:
                    img_bytes = np.asarray(bytearray(f.read()), dtype=np.uint8)
                    img = cv2.imdecode(img_bytes, cv2.IMREAD_COLOR)

                with open(self.label_files[i], 'rb') as f:
                    label_bytes = np.asarray(bytearray(f.read()), dtype=np.uint8)
                    label = cv2.imdecode(label_bytes, cv2.IMREAD_COLOR)

                if img is None or label is None:
                    continue

                img = cv2.resize(img, (256, 256))
                label = cv2.resize(label, (256, 256))

                imgs.append(img.astype(np.float32))
                labels.append(label.astype(np.float32))
            except Exception as e:
                print(f"Görüntü okunamadı: {self.data_files[i]} veya {self.label_files[i]} - {e}")

        imgs = (np.array(imgs) - self.mean) / self.stddev
        labels = (np.array(labels) - self.mean) / self.stddev
        return imgs, labels

    def denormalize(self, img):
        return np.clip((img * self.stddev + self.mean), 0, 255).astype(np.uint8)

    def train(self):
        os.makedirs(self.output_path, exist_ok=True)
        print(">>> Eğitim başlatıldı")

        for epoch in range(self.nEpochs):
            print(f"\nEpoch {epoch+1}/{self.nEpochs}")
            for i in range(self.nIters):
                imgs_inp, imgs_lab = self.read_batch()
                imgs_inp_resized = tf.image.resize(imgs_inp, (256, 256))

                self.model.train_on_batch(imgs_inp_resized, imgs_lab)

                if (i + 1) % self.print_every == 0:
                    loss = self.model.evaluate(imgs_inp_resized, imgs_lab, verbose=0)
                    print(f"[{i+1}/{self.nIters}] Loss: {loss:.4f}")

        print("\n>>> Eğitim tamamlandı.")
        self.model.save(self.model_path.replace(".h5", ".keras"))
        print(f"Model '{self.model_path}' olarak kaydedildi.")
        self.predict()  # Tahmin işlemini başlatıyoruz.

    def predict(self):
        val_files = glob.glob(os.path.join(self.val_path, "*.png"))
        print(f"{len(val_files)} adet validasyon görseli bulundu.")
        
        mean, stddev = self.mean, self.stddev
        self.model.load_weights(self.model_path.replace(".h5", ".keras"))
        print("Model ağırlıkları başarıyla yüklendi.")
        
        # label_dir dizininin son kısmındaki "Data"yı "Labels" ile değiştir
        label_dir = os.path.join(os.path.dirname(self.val_path), 'Labels')
    
        psnr_total = 0.0
        count = 0
        
        for file in val_files:
            try:
                base_name = os.path.basename(file)  # Örn: img_12.png
    
                # Görseli PIL ile oku
                img = Image.open(file)
                if img is None:
                    print(f"Geçersiz görüntü: {file}")
                    continue
    
                # Eğer görüntü RGBA (4 kanal) ise, sadece RGB'yi al
                if img.mode == 'RGBA':
                    img = img.convert('RGB')
    
                img = img.resize((256, 256))  # Görseli yeniden boyutlandır
                img_rgb = np.array(img)  # RGB formatında numpy dizisine çevir
                img_input = ((img_rgb.astype(np.float32)) - mean) / stddev
                img_input = np.expand_dims(img_input, axis=0)
    
                # Tahmin yap
                pred = self.model.predict(img_input)[0]
                pred_img = self.denormalize(pred)
    
                # Tahmini kaydet
                save_path = os.path.join(self.output_path, f"pred_{base_name}")
                pred_pil = Image.fromarray(pred_img.astype(np.uint8))
                pred_pil.save(save_path)
    
                # --- PSNR hesapla ---
                label_path = os.path.join(label_dir, base_name)
                if not os.path.exists(label_path):
                    print(f"🚫 Eşleşen label yok: {label_path}")
                    continue
    
                # Label görselini PIL ile oku
                label_img = Image.open(label_path)
                if label_img is None:
                    print(f"❌ Label okunamadı: {label_path}")
                    continue
    
                # Eğer label görseli RGBA ise, sadece RGB'yi al
                if label_img.mode == 'RGBA':
                    label_img = label_img.convert('RGB')
    
                # Label görselini yeniden boyutlandır
                label_img = label_img.resize((256, 256))
                label_img = np.array(label_img)
    
                # Her iki görüntüyü yeniden boyutlandır ve PSNR hesapla
                pred_img = np.array(pred_img)
                mse = np.mean((pred_img.astype(np.float32) - label_img.astype(np.float32)) ** 2)
                psnr = 100 if mse == 0 else 10 * log10((255 ** 2) / mse)
    
                psnr_total += psnr
                count += 1
    
                print(f"✔ {base_name} - PSNR: {psnr:.2f} dB - Kaydedildi: {save_path}")
    
            except Exception as e:
                print(f"Hata: {file} - {e}")
    
        if count > 0:
            avg_psnr = psnr_total / count
            print(f"\n📊 Ortalama PSNR: {avg_psnr:.2f} dB ({count} görsel üzerinden)")
        else:
            print("🚫 Hiçbir görsel işlenemedi.")

if __name__ == "__main__":
    train_model = SRCNN_Train(
        train_path=r"C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Dataset\Train",
        val_path=r"C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Dataset\Val\Data",
        nImgs=684,
        nEpochs=10,
        batch_size=16,
        print_every=10,
        model_path=r"C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\trained_SRCNN_model.h5",
        output_path=r"C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions"
    )
    train_model.train()
# Out:
# Number of data files: 684
# Number of label files: 684
# Calculated mean: [95.81287 95.81287 95.81287]
# Calculated stddev: [69.78387  67.10136  69.271675]
# Model: "srcnn_29"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_87 (Conv2D)                   │ (1, 256, 256, 64)           │          15,616 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_88 (Conv2D)                   │ (1, 256, 256, 32)           │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_89 (Conv2D)                   │ (1, 256, 256, 3)            │           2,403 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,099 (78.51 KB)
#  Trainable params: 20,099 (78.51 KB)
#  Non-trainable params: 0 (0.00 B)
# >>> Eğitim başlatıldı
#
# Epoch 1/10
# [10/427] Loss: 0.6892
# [20/427] Loss: 0.2580
# [30/427] Loss: 0.1484
# [40/427] Loss: 0.1297
# [50/427] Loss: 0.1434
# [60/427] Loss: 0.1316
# [70/427] Loss: 0.1044
# [80/427] Loss: 0.1023
# [90/427] Loss: 0.1349
# [100/427] Loss: 0.1000
# [110/427] Loss: 0.0736
# [120/427] Loss: 0.0904
# [130/427] Loss: 0.0984
# [140/427] Loss: 0.0787
# [150/427] Loss: 0.0592
# [160/427] Loss: 0.0715
# [170/427] Loss: 0.0611
# [180/427] Loss: 0.0640
# [190/427] Loss: 0.0566
# [200/427] Loss: 0.0530
# [210/427] Loss: 0.0849
# [220/427] Loss: 0.0493
# [230/427] Loss: 0.0541
# [240/427] Loss: 0.0473
# [250/427] Loss: 0.0632
# [260/427] Loss: 0.0535
# [270/427] Loss: 0.0458
# [280/427] Loss: 0.0500
# [290/427] Loss: 0.0484
# [300/427] Loss: 0.0493
# [310/427] Loss: 0.0435
# [320/427] Loss: 0.0438
# [330/427] Loss: 0.0401
# [340/427] Loss: 0.0419
# [350/427] Loss: 0.0384
# [360/427] Loss: 0.0443
# [370/427] Loss: 0.0454
# [380/427] Loss: 0.0351
# [390/427] Loss: 0.0317
# [400/427] Loss: 0.0359
# [410/427] Loss: 0.0439
# [420/427] Loss: 0.0471
#
# Epoch 2/10
# [10/427] Loss: 0.0378
# [20/427] Loss: 0.0269
# [30/427] Loss: 0.0469
# [40/427] Loss: 0.0392
# [50/427] Loss: 0.0379
# [60/427] Loss: 0.0377
# [70/427] Loss: 0.0323
# [80/427] Loss: 0.0403
# [90/427] Loss: 0.0368
# [100/427] Loss: 0.0353
# [110/427] Loss: 0.0236
# [120/427] Loss: 0.0279
# [130/427] Loss: 0.0324
# [140/427] Loss: 0.0303
# [150/427] Loss: 0.0432
# [160/427] Loss: 0.0336
# [170/427] Loss: 0.0275
# [180/427] Loss: 0.0250
# [190/427] Loss: 0.0306
# [200/427] Loss: 0.0256
# [210/427] Loss: 0.0301
# [220/427] Loss: 0.0228
# [230/427] Loss: 0.0338
# [240/427] Loss: 0.0375
# [250/427] Loss: 0.0214
# [260/427] Loss: 0.0241
# [270/427] Loss: 0.0290
# [280/427] Loss: 0.0298
# [290/427] Loss: 0.0231
# [300/427] Loss: 0.0271
# [310/427] Loss: 0.0276
# [320/427] Loss: 0.0228
# [330/427] Loss: 0.0403
# [340/427] Loss: 0.0276
# [350/427] Loss: 0.0286
# [360/427] Loss: 0.0224
# [370/427] Loss: 0.0271
# [380/427] Loss: 0.0360
# [390/427] Loss: 0.0283
# [400/427] Loss: 0.0240
# [410/427] Loss: 0.0221
# [420/427] Loss: 0.0286
#
# Epoch 3/10
# [10/427] Loss: 0.0169
# [20/427] Loss: 0.0214
# [30/427] Loss: 0.0233
# [40/427] Loss: 0.0358
# [50/427] Loss: 0.0289
# [60/427] Loss: 0.0287
# [70/427] Loss: 0.0301
# [80/427] Loss: 0.0266
# [90/427] Loss: 0.0228
# [100/427] Loss: 0.0231
# [110/427] Loss: 0.0236
# [120/427] Loss: 0.0249
# [130/427] Loss: 0.0303
# [140/427] Loss: 0.0287
# [150/427] Loss: 0.0244
# [160/427] Loss: 0.0293
# [170/427] Loss: 0.0179
# [180/427] Loss: 0.0234
# [190/427] Loss: 0.0219
# [200/427] Loss: 0.0238
# [210/427] Loss: 0.0193
# [220/427] Loss: 0.0211
# [230/427] Loss: 0.0234
# [240/427] Loss: 0.0205
# [250/427] Loss: 0.0188
# [260/427] Loss: 0.0244
# [270/427] Loss: 0.0177
# [280/427] Loss: 0.0271
# [290/427] Loss: 0.0290
# [300/427] Loss: 0.0170
# [310/427] Loss: 0.0229
# [320/427] Loss: 0.0183
# [330/427] Loss: 0.0169
# [340/427] Loss: 0.0163
# [350/427] Loss: 0.0266
# [360/427] Loss: 0.0245
# [370/427] Loss: 0.0275
# [380/427] Loss: 0.0167
# [390/427] Loss: 0.0187
# [400/427] Loss: 0.0269
# [410/427] Loss: 0.0189
# [420/427] Loss: 0.0273
#
# Epoch 4/10
# [10/427] Loss: 0.0259
# [20/427] Loss: 0.0178
# [30/427] Loss: 0.0182
# [40/427] Loss: 0.0195
# [50/427] Loss: 0.0239
# [60/427] Loss: 0.0234
# [70/427] Loss: 0.0263
# [80/427] Loss: 0.0171
# [90/427] Loss: 0.0221
# [100/427] Loss: 0.0197
# [110/427] Loss: 0.0212
# [120/427] Loss: 0.0137
# [130/427] Loss: 0.0293
# [140/427] Loss: 0.0145
# [150/427] Loss: 0.0350
# [160/427] Loss: 0.0203
# [170/427] Loss: 0.0180
# [180/427] Loss: 0.0180
# [190/427] Loss: 0.0186
# [200/427] Loss: 0.0221
# [210/427] Loss: 0.0273
# [220/427] Loss: 0.0179
# [230/427] Loss: 0.0216
# [240/427] Loss: 0.0217
# [250/427] Loss: 0.0233
# [260/427] Loss: 0.0271
# [270/427] Loss: 0.0181
# [280/427] Loss: 0.0144
# [290/427] Loss: 0.0192
# [300/427] Loss: 0.0207
# [310/427] Loss: 0.0154
# [320/427] Loss: 0.0183
# [330/427] Loss: 0.0199
# [340/427] Loss: 0.0253
# [350/427] Loss: 0.0232
# [360/427] Loss: 0.0163
# [370/427] Loss: 0.0161
# [380/427] Loss: 0.0159
# [390/427] Loss: 0.0208
# [400/427] Loss: 0.0245
# [410/427] Loss: 0.0192
# [420/427] Loss: 0.0174
#
# Epoch 5/10
# [10/427] Loss: 0.0295
# [20/427] Loss: 0.0137
# [30/427] Loss: 0.0166
# [40/427] Loss: 0.0192
# [50/427] Loss: 0.0211
# [60/427] Loss: 0.0189
# [70/427] Loss: 0.0225
# [80/427] Loss: 0.0196
# [90/427] Loss: 0.0158
# [100/427] Loss: 0.0168
# [110/427] Loss: 0.0208
# [120/427] Loss: 0.0182
# [130/427] Loss: 0.0170
# [140/427] Loss: 0.0170
# [150/427] Loss: 0.0231
# [160/427] Loss: 0.0188
# [170/427] Loss: 0.0161
# [180/427] Loss: 0.0243
# [190/427] Loss: 0.0182
# [200/427] Loss: 0.0173
# [210/427] Loss: 0.0210
# [220/427] Loss: 0.0177
# [230/427] Loss: 0.0226
# [240/427] Loss: 0.0176
# [250/427] Loss: 0.0171
# [260/427] Loss: 0.0223
# [270/427] Loss: 0.0152
# [280/427] Loss: 0.0175
# [290/427] Loss: 0.0161
# [300/427] Loss: 0.0196
# [310/427] Loss: 0.0199
# [320/427] Loss: 0.0223
# [330/427] Loss: 0.0164
# [340/427] Loss: 0.0116
# [350/427] Loss: 0.0212
# [360/427] Loss: 0.0183
# [370/427] Loss: 0.0189
# [380/427] Loss: 0.0189
# [390/427] Loss: 0.0232
# [400/427] Loss: 0.0126
# [410/427] Loss: 0.0190
# [420/427] Loss: 0.0239
#
# Epoch 6/10
# [10/427] Loss: 0.0169
# [20/427] Loss: 0.0182
# [30/427] Loss: 0.0145
# [40/427] Loss: 0.0134
# [50/427] Loss: 0.0240
# [60/427] Loss: 0.0150
# [70/427] Loss: 0.0137
# [80/427] Loss: 0.0132
# [90/427] Loss: 0.0203
# [100/427] Loss: 0.0160
# [110/427] Loss: 0.0156
# [120/427] Loss: 0.0266
# [130/427] Loss: 0.0182
# [140/427] Loss: 0.0151
# [150/427] Loss: 0.0151
# [160/427] Loss: 0.0168
# [170/427] Loss: 0.0212
# [180/427] Loss: 0.0176
# [190/427] Loss: 0.0155
# [200/427] Loss: 0.0240
# [210/427] Loss: 0.0140
# [220/427] Loss: 0.0203
# [230/427] Loss: 0.0128
# [240/427] Loss: 0.0121
# [250/427] Loss: 0.0193
# [260/427] Loss: 0.0200
# [270/427] Loss: 0.0163
# [280/427] Loss: 0.0124
# [290/427] Loss: 0.0141
# [300/427] Loss: 0.0149
# [310/427] Loss: 0.0132
# [320/427] Loss: 0.0160
# [330/427] Loss: 0.0143
# [340/427] Loss: 0.0227
# [350/427] Loss: 0.0143
# [360/427] Loss: 0.0182
# [370/427] Loss: 0.0192
# [380/427] Loss: 0.0214
# [390/427] Loss: 0.0197
# [400/427] Loss: 0.0222
# [410/427] Loss: 0.0157
# [420/427] Loss: 0.0152
#
# Epoch 7/10
# [10/427] Loss: 0.0190
# [20/427] Loss: 0.0123
# [30/427] Loss: 0.0165
# [40/427] Loss: 0.0145
# [50/427] Loss: 0.0227
# [60/427] Loss: 0.0214
# [70/427] Loss: 0.0164
# [80/427] Loss: 0.0148
# [90/427] Loss: 0.0154
# [100/427] Loss: 0.0159
# [110/427] Loss: 0.0217
# [120/427] Loss: 0.0177
# [130/427] Loss: 0.0128
# [140/427] Loss: 0.0173
# [150/427] Loss: 0.0208
# [160/427] Loss: 0.0221
# [170/427] Loss: 0.0176
# [180/427] Loss: 0.0157
# [190/427] Loss: 0.0149
# [200/427] Loss: 0.0145
# [210/427] Loss: 0.0182
# [220/427] Loss: 0.0160
# [230/427] Loss: 0.0164
# [240/427] Loss: 0.0135
# [250/427] Loss: 0.0182
# [260/427] Loss: 0.0129
# [270/427] Loss: 0.0171
# [280/427] Loss: 0.0161
# [290/427] Loss: 0.0154
# [300/427] Loss: 0.0141
# [310/427] Loss: 0.0223
# [320/427] Loss: 0.0147
# [330/427] Loss: 0.0129
# [340/427] Loss: 0.0190
# [350/427] Loss: 0.0171
# [360/427] Loss: 0.0145
# [370/427] Loss: 0.0142
# [380/427] Loss: 0.0162
# [390/427] Loss: 0.0158
# [400/427] Loss: 0.0155
# [410/427] Loss: 0.0151
# [420/427] Loss: 0.0141
#
# Epoch 8/10
# [10/427] Loss: 0.0164
# [20/427] Loss: 0.0232
# [30/427] Loss: 0.0187
# [40/427] Loss: 0.0191
# [50/427] Loss: 0.0177
# [60/427] Loss: 0.0110
# [70/427] Loss: 0.0175
# [80/427] Loss: 0.0155
# [90/427] Loss: 0.0207
# [100/427] Loss: 0.0145
# [110/427] Loss: 0.0143
# [120/427] Loss: 0.0130
# [130/427] Loss: 0.0125
# [140/427] Loss: 0.0181
# [150/427] Loss: 0.0163
# [160/427] Loss: 0.0172
# [170/427] Loss: 0.0150
# [180/427] Loss: 0.0226
# [190/427] Loss: 0.0166
# [200/427] Loss: 0.0150
# [210/427] Loss: 0.0173
# [220/427] Loss: 0.0129
# [230/427] Loss: 0.0184
# [240/427] Loss: 0.0185
# [250/427] Loss: 0.0170
# [260/427] Loss: 0.0176
# [270/427] Loss: 0.0229
# [280/427] Loss: 0.0205
# [290/427] Loss: 0.0166
# [300/427] Loss: 0.0155
# [310/427] Loss: 0.0126
# [320/427] Loss: 0.0201
# [330/427] Loss: 0.0140
# [340/427] Loss: 0.0168
# [350/427] Loss: 0.0162
# [360/427] Loss: 0.0169
# [370/427] Loss: 0.0159
# [380/427] Loss: 0.0152
# [390/427] Loss: 0.0164
# [400/427] Loss: 0.0199
# [410/427] Loss: 0.0129
# [420/427] Loss: 0.0230
#
# Epoch 9/10
# [10/427] Loss: 0.0168
# [20/427] Loss: 0.0150
# [30/427] Loss: 0.0134
# [40/427] Loss: 0.0177
# [50/427] Loss: 0.0142
# [60/427] Loss: 0.0212
# [70/427] Loss: 0.0151
# [80/427] Loss: 0.0136
# [90/427] Loss: 0.0201
# [100/427] Loss: 0.0192
# [110/427] Loss: 0.0165
# [120/427] Loss: 0.0163
# [130/427] Loss: 0.0127
# [140/427] Loss: 0.0186
# [150/427] Loss: 0.0209
# [160/427] Loss: 0.0182
# [170/427] Loss: 0.0170
# [180/427] Loss: 0.0123
# [190/427] Loss: 0.0200
# [200/427] Loss: 0.0135
# [210/427] Loss: 0.0176
# [220/427] Loss: 0.0201
# [230/427] Loss: 0.0169
# [240/427] Loss: 0.0194
# [250/427] Loss: 0.0190
# [260/427] Loss: 0.0183
# [270/427] Loss: 0.0192
# [280/427] Loss: 0.0148
# [290/427] Loss: 0.0123
# [300/427] Loss: 0.0135
# [310/427] Loss: 0.0154
# [320/427] Loss: 0.0183
# [330/427] Loss: 0.0150
# [340/427] Loss: 0.0085
# [350/427] Loss: 0.0154
# [360/427] Loss: 0.0185
# [370/427] Loss: 0.0127
# [380/427] Loss: 0.0128
# [390/427] Loss: 0.0119
# [400/427] Loss: 0.0108
# [410/427] Loss: 0.0195
# [420/427] Loss: 0.0227
#
# Epoch 10/10
# [10/427] Loss: 0.0130
# [20/427] Loss: 0.0107
# [30/427] Loss: 0.0203
# [40/427] Loss: 0.0149
# [50/427] Loss: 0.0147
# [60/427] Loss: 0.0187
# [70/427] Loss: 0.0125
# [80/427] Loss: 0.0107
# [90/427] Loss: 0.0094
# [100/427] Loss: 0.0133
# [110/427] Loss: 0.0131
# [120/427] Loss: 0.0163
# [130/427] Loss: 0.0147
# [140/427] Loss: 0.0147
# [150/427] Loss: 0.0167
# [160/427] Loss: 0.0110
# [170/427] Loss: 0.0121
# [180/427] Loss: 0.0201
# [190/427] Loss: 0.0170
# [200/427] Loss: 0.0101
# [210/427] Loss: 0.0128
# [220/427] Loss: 0.0160
# [230/427] Loss: 0.0177
# [240/427] Loss: 0.0207
# [250/427] Loss: 0.0149
# [260/427] Loss: 0.0145
# [270/427] Loss: 0.0156
# [280/427] Loss: 0.0151
# [290/427] Loss: 0.0147
# [300/427] Loss: 0.0101
# [310/427] Loss: 0.0146
# [320/427] Loss: 0.0173
# [330/427] Loss: 0.0201
# [340/427] Loss: 0.0145
# [350/427] Loss: 0.0156
# [360/427] Loss: 0.0146
# [370/427] Loss: 0.0137
# [380/427] Loss: 0.0154
# [390/427] Loss: 0.0128
# [400/427] Loss: 0.0114
# [410/427] Loss: 0.0100
# [420/427] Loss: 0.0117
#
# >>> Eğitim tamamlandı.
# Model 'C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\trained_SRCNN_model.h5' olarak kaydedildi.
# 170 adet validasyon görseli bulundu.
# Model ağırlıkları başarıyla yüklendi.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# ✔ 0.png - PSNR: 29.80 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_0.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# ✔ 1.png - PSNR: 26.86 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# ✔ 10.png - PSNR: 28.28 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_10.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# ✔ 100.png - PSNR: 32.23 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_100.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# ✔ 101.png - PSNR: 28.87 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_101.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# ✔ 102.png - PSNR: 30.83 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_102.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# ✔ 103.png - PSNR: 27.60 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_103.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# ✔ 104.png - PSNR: 29.39 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_104.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# ✔ 105.png - PSNR: 27.61 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_105.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# ✔ 106.png - PSNR: 27.97 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_106.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# ✔ 107.png - PSNR: 33.45 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_107.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# ✔ 108.png - PSNR: 25.94 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_108.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# ✔ 109.png - PSNR: 30.39 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_109.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# ✔ 11.png - PSNR: 29.30 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_11.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# ✔ 110.png - PSNR: 28.79 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_110.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# ✔ 111.png - PSNR: 30.99 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_111.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# ✔ 112.png - PSNR: 29.44 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_112.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# ✔ 113.png - PSNR: 31.13 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_113.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# ✔ 114.png - PSNR: 27.94 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_114.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# ✔ 115.png - PSNR: 29.40 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_115.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# ✔ 116.png - PSNR: 37.52 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_116.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# ✔ 117.png - PSNR: 39.05 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_117.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# ✔ 118.png - PSNR: 28.32 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_118.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# ✔ 119.png - PSNR: 29.59 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_119.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# ✔ 12.png - PSNR: 30.95 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_12.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# ✔ 120.png - PSNR: 29.86 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_120.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# ✔ 121.png - PSNR: 34.97 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_121.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# ✔ 122.png - PSNR: 31.83 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_122.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# ✔ 123.png - PSNR: 33.14 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_123.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# ✔ 124.png - PSNR: 31.08 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_124.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# ✔ 125.png - PSNR: 32.72 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_125.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# ✔ 126.png - PSNR: 25.58 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_126.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# ✔ 127.png - PSNR: 31.64 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_127.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# ✔ 128.png - PSNR: 33.22 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_128.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# ✔ 129.png - PSNR: 27.41 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_129.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# ✔ 13.png - PSNR: 26.75 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_13.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# ✔ 130.png - PSNR: 28.41 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_130.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# ✔ 131.png - PSNR: 24.45 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_131.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# ✔ 132.png - PSNR: 32.10 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_132.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# ✔ 133.png - PSNR: 32.15 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_133.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# ✔ 134.png - PSNR: 34.26 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_134.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# ✔ 135.png - PSNR: 31.36 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_135.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# ✔ 136.png - PSNR: 30.81 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_136.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# ✔ 137.png - PSNR: 29.61 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_137.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# ✔ 138.png - PSNR: 31.16 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_138.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# ✔ 139.png - PSNR: 28.09 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_139.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# ✔ 14.png - PSNR: 27.92 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_14.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# ✔ 140.png - PSNR: 28.35 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_140.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# ✔ 141.png - PSNR: 33.24 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_141.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# ✔ 142.png - PSNR: 26.20 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_142.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# ✔ 143.png - PSNR: 25.41 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_143.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# ✔ 144.png - PSNR: 33.15 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_144.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# ✔ 145.png - PSNR: 30.67 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_145.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# ✔ 146.png - PSNR: 26.75 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_146.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# ✔ 147.png - PSNR: 28.95 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_147.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# ✔ 148.png - PSNR: 29.36 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_148.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# ✔ 149.png - PSNR: 30.25 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_149.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# ✔ 15.png - PSNR: 29.67 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_15.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# ✔ 150.png - PSNR: 26.78 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_150.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# ✔ 151.png - PSNR: 36.93 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_151.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# ✔ 152.png - PSNR: 33.37 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_152.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# ✔ 153.png - PSNR: 30.48 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_153.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# ✔ 154.png - PSNR: 28.18 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_154.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# ✔ 155.png - PSNR: 41.99 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_155.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# ✔ 156.png - PSNR: 28.63 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_156.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# ✔ 157.png - PSNR: 34.55 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_157.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# ✔ 158.png - PSNR: 28.25 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_158.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# ✔ 159.png - PSNR: 28.51 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_159.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# ✔ 16.png - PSNR: 27.25 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_16.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# ✔ 160.png - PSNR: 28.66 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_160.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# ✔ 161.png - PSNR: 27.07 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_161.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# ✔ 162.png - PSNR: 27.79 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_162.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# ✔ 163.png - PSNR: 37.45 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_163.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# ✔ 164.png - PSNR: 28.85 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_164.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# ✔ 165.png - PSNR: 31.21 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_165.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# ✔ 166.png - PSNR: 28.69 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_166.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# ✔ 167.png - PSNR: 29.34 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_167.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# ✔ 168.png - PSNR: 26.96 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_168.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# ✔ 169.png - PSNR: 32.79 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_169.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# ✔ 17.png - PSNR: 32.73 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_17.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# ✔ 18.png - PSNR: 29.56 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_18.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# ✔ 19.png - PSNR: 31.35 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_19.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# ✔ 2.png - PSNR: 34.95 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_2.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# ✔ 20.png - PSNR: 39.66 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_20.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# ✔ 21.png - PSNR: 31.21 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_21.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# ✔ 22.png - PSNR: 27.79 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_22.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# ✔ 23.png - PSNR: 30.24 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_23.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# ✔ 24.png - PSNR: 32.03 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_24.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# ✔ 25.png - PSNR: 28.42 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_25.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# ✔ 26.png - PSNR: 29.47 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_26.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# ✔ 27.png - PSNR: 30.36 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_27.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# ✔ 28.png - PSNR: 31.51 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_28.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# ✔ 29.png - PSNR: 36.58 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_29.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# ✔ 3.png - PSNR: 29.31 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_3.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# ✔ 30.png - PSNR: 18.79 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_30.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# ✔ 31.png - PSNR: 26.66 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_31.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# ✔ 32.png - PSNR: 32.58 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_32.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# ✔ 33.png - PSNR: 30.37 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_33.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# ✔ 34.png - PSNR: 32.65 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_34.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# ✔ 35.png - PSNR: 25.78 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_35.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# ✔ 36.png - PSNR: 32.64 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_36.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# ✔ 37.png - PSNR: 26.09 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_37.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# ✔ 38.png - PSNR: 37.12 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_38.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# ✔ 39.png - PSNR: 35.82 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_39.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# ✔ 4.png - PSNR: 26.22 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_4.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# ✔ 40.png - PSNR: 26.54 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_40.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# ✔ 41.png - PSNR: 37.23 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_41.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# ✔ 42.png - PSNR: 31.76 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_42.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# ✔ 43.png - PSNR: 29.09 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_43.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# ✔ 44.png - PSNR: 28.14 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_44.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# ✔ 45.png - PSNR: 31.83 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_45.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# ✔ 46.png - PSNR: 30.28 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_46.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# ✔ 47.png - PSNR: 27.90 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_47.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# ✔ 48.png - PSNR: 34.48 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_48.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# ✔ 49.png - PSNR: 26.66 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_49.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# ✔ 5.png - PSNR: 35.49 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_5.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# ✔ 50.png - PSNR: 29.76 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_50.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# ✔ 51.png - PSNR: 30.47 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_51.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# ✔ 52.png - PSNR: 35.76 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_52.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# ✔ 53.png - PSNR: 30.46 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_53.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# ✔ 54.png - PSNR: 30.51 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_54.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# ✔ 55.png - PSNR: 32.74 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_55.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# ✔ 56.png - PSNR: 27.09 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_56.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# ✔ 57.png - PSNR: 27.68 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_57.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# ✔ 58.png - PSNR: 29.12 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_58.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# ✔ 59.png - PSNR: 28.21 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_59.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# ✔ 6.png - PSNR: 30.65 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_6.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# ✔ 60.png - PSNR: 38.65 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_60.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# ✔ 61.png - PSNR: 33.06 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_61.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# ✔ 62.png - PSNR: 27.23 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_62.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# ✔ 63.png - PSNR: 34.45 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_63.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# ✔ 64.png - PSNR: 29.26 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_64.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# ✔ 65.png - PSNR: 24.70 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_65.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# ✔ 66.png - PSNR: 34.25 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_66.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# ✔ 67.png - PSNR: 31.67 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_67.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# ✔ 68.png - PSNR: 27.03 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_68.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# ✔ 69.png - PSNR: 30.24 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_69.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# ✔ 7.png - PSNR: 28.60 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_7.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# ✔ 70.png - PSNR: 27.89 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_70.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# ✔ 71.png - PSNR: 33.86 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_71.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# ✔ 72.png - PSNR: 30.72 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_72.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# ✔ 73.png - PSNR: 28.53 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_73.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# ✔ 74.png - PSNR: 30.19 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_74.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# ✔ 75.png - PSNR: 30.29 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_75.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# ✔ 76.png - PSNR: 26.18 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_76.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# ✔ 77.png - PSNR: 29.79 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_77.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# ✔ 78.png - PSNR: 29.26 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_78.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# ✔ 79.png - PSNR: 33.35 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_79.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# ✔ 8.png - PSNR: 32.68 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_8.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# ✔ 80.png - PSNR: 32.07 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_80.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# ✔ 81.png - PSNR: 33.16 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_81.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# ✔ 82.png - PSNR: 32.59 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_82.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# ✔ 83.png - PSNR: 28.41 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_83.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# ✔ 84.png - PSNR: 28.68 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_84.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# ✔ 85.png - PSNR: 31.16 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_85.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# ✔ 86.png - PSNR: 29.85 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_86.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# ✔ 87.png - PSNR: 35.51 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_87.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# ✔ 88.png - PSNR: 28.85 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_88.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# ✔ 89.png - PSNR: 30.51 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_89.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# ✔ 9.png - PSNR: 25.20 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_9.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# ✔ 90.png - PSNR: 27.14 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_90.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# ✔ 91.png - PSNR: 29.58 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_91.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# ✔ 92.png - PSNR: 28.86 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_92.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# ✔ 93.png - PSNR: 30.05 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_93.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# ✔ 94.png - PSNR: 30.39 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_94.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# ✔ 95.png - PSNR: 28.00 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_95.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# ✔ 96.png - PSNR: 30.58 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_96.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# ✔ 97.png - PSNR: 29.60 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_97.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# ✔ 98.png - PSNR: 33.02 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_98.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# ✔ 99.png - PSNR: 30.90 dB - Kaydedildi: C:\Users\melis\OneDrive\Masaüstü\image_processing_project\Super-Resolution-master\Predictions\pred_99.png
#
# 📊 Ortalama PSNR: 30.37 dB (170 görsel üzerinden)
